# %% [markdown]
# # PINNs, part B — the 1D Poisson equation
#
# **DesignSafe AI Training**
#
# [![Try on DesignSafe](https://raw.githubusercontent.com/DesignSafe-CI/training-ai/main/DesignSafe-Badge.svg)](https://jupyter.designsafe-ci.org/hub/user-redirect/lab/tree/CommunityData/Training/2026-SPARC/Day3/3b-SciML/04b-pinn-poisson.ipynb)
#
# > Ported from the [SciML course](https://kks32-courses.github.io/sciml/01-pinns/poisson.html)
# > (Krishna Kumar).
#
# Part A solved an initial-value problem in time. This is a **boundary**-value
# problem in space, and it is the same equation the MLP notebook sampled when it fit
# $\sin(\pi x)$ from 15 noisy points — now solved from the equation instead of from
# data.
#
# The new question here is how boundary conditions get enforced: as a penalty in
# the loss (**soft**), or by construction so they cannot be violated (**hard**).
#
# ---

# %%
# Capture figures as notebook outputs. The course notebooks run in a
# live JupyterLab where this is implicit; the published book renders
# saved outputs, so without it every plot is lost.
# %matplotlib inline

# %% [markdown]
# ## Introduction: The 1D Poisson Problem
#
# **Exercise:** [![Open in Colab](https://img.shields.io/badge/Open%20in-Colab-F9AB00?style=flat-square&logo=googlecolab)](https://colab.research.google.com/github/kks32-courses/sciml/blob/main/docs/01-pinns/poisson-exercise.ipynb)
# **Solution:** [![Open in Colab](https://img.shields.io/badge/Open%20in-Colab-F9AB00?style=flat-square&logo=googlecolab)](https://colab.research.google.com/github/kks32-courses/sciml/blob/main/docs/01-pinns/poisson.ipynb)
#
# In this notebook, we tackle the one-dimensional Poisson equation, a fundamental elliptic partial differential equation that describes many steady-state physical phenomena, such as heat conduction, electrostatics, and ideal fluid flow.
#
# Our specific problem is to find the solution $u(x)$ that satisfies:
#
# **Governing Equation:**
# $$\frac{d^2u}{dx^2} + \pi \sin(\pi x) = 0, \quad \text{for } x \in [0, 1]$$
#
# **Boundary Conditions (BCs):**
# $$u(0) = 0 \quad \text{and} \quad u(1) = 0$$
#
# This is a boundary value problem with Dirichlet conditions (i.e., the value of the solution is specified at the boundaries).
#
# **Analytical Solution:**
# For validation purposes, this problem has a known exact solution, which can be found by integrating the equation twice and applying the boundary conditions:
# $$u_{\text{exact}}(x) = \frac{1}{\pi} \sin(\pi x)$$
#
# Our goal is to train a Physics-Informed Neural Network (PINN) to discover this solution without being given the analytical form, using only the governing equation and its boundary conditions. We will explore two common methods for enforcing the boundary conditions:
#
# 1.  **Soft Constraints:** Adding a penalty term to the loss function for boundary violations.
# 2.  **Hard Constraints:** Modifying the network architecture to satisfy the boundary conditions by construction.

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm

# Set up plot styles
plt.style.use('seaborn-v0_8-whitegrid')
plt.rcParams.update({'font.size': 14, 'figure.figsize': (10, 6)})

# Set random seeds for reproducibility
torch.manual_seed(42)
np.random.seed(42)

# Check for available device (CUDA, MPS, or CPU)
if torch.cuda.is_available():
    device = torch.device('cuda')
    print(f"Using CUDA GPU: {torch.cuda.get_device_name()}")
elif torch.backends.mps.is_available():
    device = torch.device('mps')
    print("Using Apple Metal Performance Shaders (MPS)")
else:
    device = torch.device('cpu')
    print("Using CPU")
print(f"Using device: {device}")

# Analytical solution for comparison
def analytical_solution(x):
    """Analytical solution: u(x) = (1/π)sin(πx)"""
    return (1 / np.pi) * np.sin(np.pi * x)

# Generate test points for plotting
x_test_np = np.linspace(0, 1, 200)
u_true_np = analytical_solution(x_test_np)
x_test = torch.tensor(x_test_np.reshape(-1, 1), dtype=torch.float32).to(device)
# Out:
# Using Apple Metal Performance Shaders (MPS)
# Using device: mps

# %% [markdown]
# ### **Stage 1: The Soft Constraint Approach (Weak Enforcement)**
#
# The most common way to enforce boundary conditions in a PINN is the "soft" or "weak" method. The core idea is to treat the boundary conditions just like the PDE itself: as a component of the total loss function that we want to minimize.
#
# **How it works:**
#
# 1.  We define a **boundary loss** term, $\mathcal{L}_{BC}$, which measures the mean squared error between the network's predictions at the boundary points and the true boundary values.
# 2.  This boundary loss is added to the PDE residual loss, $\mathcal{L}*{PDE}$, often with a weighting factor $\lambda*{BC}$.
# 3.  The total loss is: $\mathcal{L}*{\text{total}} = \mathcal{L}*{PDE} + \lambda\_{BC} \mathcal{L}_{BC}$.
#
# By minimizing $\mathcal{L}*{\text{total}}$, the optimizer is encouraged to find a solution that *approximately* satisfies the boundary conditions. Satisfaction is not guaranteed by the network's structure but is instead a goal of the optimization. The weight $\lambda*{BC}$ is a hyperparameter that balances how strictly the boundary conditions are enforced relative to the PDE.
#
# #### **PINN Definition and Loss Functions**
#
# First, we define our neural network and the two loss components.

# %%
class PINN(nn.Module):
    """Standard Feedforward Neural Network for PINN"""
    def __init__(self, input_size=1, hidden_size=32, output_size=1, num_layers=3):
        super(PINN, self).__init__()
        layers = []
        layers.append(nn.Linear(input_size, hidden_size))
        layers.append(nn.Tanh())
        for _ in range(num_layers - 2):
            layers.append(nn.Linear(hidden_size, hidden_size))
            layers.append(nn.Tanh())
        layers.append(nn.Linear(hidden_size, output_size))
        self.network = nn.Sequential(*layers)

    def forward(self, x):
        return self.network(x)

def pde_loss(model, x_interior):
    """Computes the PDE residual loss: d²u/dx² + πsin(πx) = 0"""
    x_interior.requires_grad_(True)
    u = model(x_interior)
    
    # First derivative
    du_dx = torch.autograd.grad(u, x_interior, torch.ones_like(u), create_graph=True)[0]
    # Second derivative
    d2u_dx2 = torch.autograd.grad(du_dx, x_interior, torch.ones_like(du_dx), create_graph=True)[0]
    
    forcing_term = torch.pi * torch.sin(torch.pi * x_interior)
    pde_residual = d2u_dx2 + forcing_term
    
    return torch.mean(pde_residual**2)

def boundary_loss(model, x_boundary):
    """Computes boundary loss for u(0)=0 and u(1)=0"""
    u_boundary = model(x_boundary)
    # The target values are 0 for both boundaries
    return torch.mean(u_boundary**2)

# %% [markdown]
# #### **Training the Soft-Constraint PINN**
#
# Now, we set up the training loop. We sample points inside the domain (collocation points) to enforce the PDE and points on the boundary to enforce the BCs. We choose a large weight `lambda_bc` to strongly encourage the network to satisfy the boundary conditions.

# %%
def train_pinn_soft(model, epochs=15000, lr=0.001, lambda_bc=1000.0):
    """Trains the PINN using the soft constraint method."""
    optimizer = optim.Adam(model.parameters(), lr=lr)
    
    # Collocation points
    n_interior = 500
    x_interior = torch.rand(n_interior, 1, device=device)
    
    # Boundary points
    x_boundary = torch.tensor([[0.0], [1.0]], device=device)
    
    print(f"\n--- Training Soft-Constraint PINN (lambda_bc = {lambda_bc}) ---")
    losses = {'total': [], 'pde': [], 'boundary': []}
    
    pbar = tqdm(range(epochs), desc="Training Soft-Constraint PINN", ncols=100)
    for epoch in pbar:
        optimizer.zero_grad()
        
        # Compute losses
        loss_pde = pde_loss(model, x_interior)
        loss_bc = boundary_loss(model, x_boundary)
        
        # Total loss
        total_loss = loss_pde + lambda_bc * loss_bc
        
        # Backpropagation
        total_loss.backward()
        optimizer.step()
        
        # Store and display losses
        losses['total'].append(total_loss.item())
        losses['pde'].append(loss_pde.item())
        losses['boundary'].append(loss_bc.item())
        pbar.set_postfix({
            'Loss': f'{total_loss.item():.2e}',
            'PDE': f'{loss_pde.item():.2e}',
            'BC': f'{loss_bc.item():.2e}'
        })
        
    pbar.close()
    return model, losses

# Instantiate and train the soft-constraint model
pinn_soft = PINN().to(device)
pinn_soft_trained, losses_soft = train_pinn_soft(pinn_soft)

# Get predictions
pinn_soft_trained.eval()
with torch.no_grad():
    u_pred_soft = pinn_soft_trained(x_test).cpu().numpy()

# Plot results for the soft-constraint model
plt.figure(figsize=(10, 6))
plt.plot(x_test_np, u_true_np, 'k-', label='Analytical Solution', linewidth=3)
plt.plot(x_test_np, u_pred_soft, 'r--', label='PINN (Soft Constraint)', linewidth=2.5)
plt.title('Soft Constraint PINN vs. Analytical Solution')
plt.xlabel('Position (x)')
plt.ylabel('Displacement (u)')
plt.legend()
plt.grid(True, alpha=0.5)
plt.show()

# Check boundary values
print(f"Predicted u(0): {u_pred_soft[0][0]:.4e}")
print(f"Predicted u(1): {u_pred_soft[-1][0]:.4e}")
# Out:
# --- Training Soft-Constraint PINN (lambda_bc = 1000.0) ---
# Training Soft-Constraint PINN:   0%|                                      | 0/15000 [00:00<?, ?it/s]
# Training Soft-Constraint PINN:   0%| | 0/15000 [00:00<?, ?it/s, Loss=4.47e+01, PDE=6.20e+00, BC=3.85
# Training Soft-Constraint PINN:   0%| | 1/15000 [00:00<26:38,  9.38it/s, Loss=4.47e+01, PDE=6.20e+00,
# Training Soft-Constraint PINN:   0%| | 1/15000 [00:00<26:38,  9.38it/s, Loss=2.57e+01, PDE=6.07e+00,
# Training Soft-Constraint PINN:   0%| | 1/15000 [00:00<26:38,  9.38it/s, Loss=1.38e+01, PDE=5.94e+00,
# Training Soft-Constraint PINN:   0%| | 1/15000 [00:00<26:38,  9.38it/s, Loss=8.50e+00, PDE=5.82e+00,
# Training Soft-Constraint PINN:   0%| | 1/15000 [00:00<26:38,  9.38it/s, Loss=8.42e+00, PDE=5.71e+00,
# Training Soft-Constraint PINN:   0%| | 1/15000 [00:00<26:38,  9.38it/s, Loss=1.11e+01, PDE=5.63e+00,
# Training Soft-Constraint PINN:   0%| | 1/15000 [00:00<26:38,  9.38it/s, Loss=1.37e+01, PDE=5.57e+00,
# Training Soft-Constraint PINN:   0%| | 1/15000 [00:00<26:38,  9.38it/s, Loss=1.47e+01, PDE=5.54e+00,
# Training Soft-Constraint PINN:   0%| | 1/15000 [00:00<26:38,  9.38it/s, Loss=1.40e+01, PDE=5.53e+00,
# Training Soft-Constraint PINN:   0%| | 1/15000 [00:00<26:38,  9.38it/s, Loss=1.20e+01, PDE=5.54e+00,
# Training Soft-Constraint PINN:   0%| | 1/15000 [00:00<26:38,  9.38it/s, Loss=9.53e+00, PDE=5.56e+00,
# Training Soft-Constraint PINN:   0%| | 1/15000 [00:00<26:38,  9.38it/s, Loss=7.40e+00, PDE=5.59e+00,
# Training Soft-Constraint PINN:   0%| | 1/15000 [00:00<26:38,  9.38it/s, Loss=6.06e+00, PDE=5.62e+00,
# Training Soft-Constraint PINN:   0%| | 1/15000 [00:00<26:38,  9.38it/s, Loss=5.65e+00, PDE=5.65e+00,
# Training Soft-Constraint PINN:   0%| | 1/15000 [00:00<26:38,  9.38it/s, Loss=6.05e+00, PDE=5.68e+00,
# Training Soft-Constraint PINN:   0%| | 1/15000 [00:00<26:38,  9.38it/s, Loss=6.89e+00, PDE=5.70e+00,
# Training Soft-Constraint PINN:   0%| | 1/15000 [00:00<26:38,  9.38it/s, Loss=7.75e+00, PDE=5.71e+00,
# Training Soft-Constraint PINN:   0%| | 1/15000 [00:00<26:38,  9.38it/s, Loss=8.27e+00, PDE=5.71e+00,
# Training Soft-Constraint PINN:   0%| | 1/15000 [00:00<26:38,  9.38it/s, Loss=8.32e+00, PDE=5.71e+00,
# Training Soft-Constraint PINN:   0%| | 1/15000 [00:00<26:38,  9.38it/s, Loss=7.92e+00, PDE=5.69e+00,
# Training Soft-Constraint PINN:   0%| | 1/15000 [00:00<26:38,  9.38it/s, Loss=7.27e+00, PDE=5.67e+00,
# Training Soft-Constraint PINN:   0%| | 1/15000 [00:00<26:38,  9.38it/s, Loss=6.58e+00, PDE=5.64e+00,
# Training Soft-Constraint PINN:   0%| | 1/15000 [00:00<26:38,  9.38it/s, Loss
# Training Soft-Constraint PINN:  99%|▉| 14903/15000 [00:52<00:00, 271.10it/s, Loss=3.74e-04, PDE=1.77
# Training Soft-Constraint PINN:  99%|▉| 14903/15000 [00:52<00:00, 271.10it/s, Loss=4.08e-04, PDE=1.76
# Training Soft-Constraint PINN: 100%|▉| 14932/15000 [00:52<00:00, 274.91it/s, Loss=4.08e-04, PDE=1.76
# Training Soft-Constraint PINN: 100%|▉| 14932/15000 [00:52<00:00, 274.91it/s, Loss=3.23e-04, PDE=1.77
# Training Soft-Constraint PINN: 100%|▉| 14932/15000 [00:52<00:00, 274.91it/s, Loss=2.11e-04, PDE=1.76
# Training Soft-Constraint PINN: 100%|▉| 14932/15000 [00:52<00:00, 274.91it/s, Loss=1.79e-04, PDE=1.76
# Training Soft-Constraint PINN: 100%|▉| 14932/15000 [00:52<00:00, 274.91it/s, Loss=2.32e-04, PDE=1.77
# Training Soft-Constraint PINN: 100%|▉| 14932/15000 [00:52<00:00, 274.91it/s, Loss=2.92e-04, PDE=1.76
# Training Soft-Constraint PINN: 100%|▉| 14932/15000 [00:52<00:00, 274.91it/s, Loss=2.94e-04, PDE=1.77
# Training Soft-Constraint PINN: 100%|▉| 14932/15000 [00:52<00:00, 274.91it/s, Loss=2.49e-04, PDE=1.76
# Training Soft-Constraint PINN: 100%|▉| 14932/15000 [00:52<00:00, 274.91it/s, Loss=2.04e-04, PDE=1.76
# Training Soft-Constraint PINN: 100%|▉| 14932/15000 [00:52<00:00, 274.91it/s, Loss=1.89e-04, PDE=1.76
# Training Soft-Constraint PINN: 100%|▉| 14932/15000 [00:52<00:00, 274.91it/s, Loss=2.02e-04, PDE=1.76
# Training Soft-Constraint PINN: 100%|▉| 14932/15000 [00:52<00:00, 274.91it/s, Loss=2.23e-04, PDE=1.76
# Training Soft-Constraint PINN: 100%|▉| 14932/15000 [00:52<00:00, 274.91it/s, Loss=2.36e-04, PDE=1.76
# Training Soft-Constraint PINN: 100%|▉| 14932/15000 [00:52<00:00, 274.91it/s, Loss=2.27e-04, PDE=1.76
# Training Soft-Constraint PINN: 100%|▉| 14932/15000 [00:52<00:00, 274.91it/s, Loss=2.03e-04, PDE=1.76
# Training Soft-Constraint PINN: 100%|▉| 14932/15000 [00:52<00:00, 274.91it/s, Loss=1.81e-04, PDE=1.76
# Training Soft-Constraint PINN: 100%|▉| 14932/15000 [00:52<00:00, 274.91it/s, Loss=1.80e-04, PDE=1.76
# Training Soft-Constraint PINN: 100%|▉| 14932/15000 [00:52<00:00, 274.91it/s, Loss=1.96e-04, PDE=1.76
# Training Soft-Constraint PINN: 100%|▉| 14932/15000 [00:52<00:00, 274.91it/s, Loss=2.10e-04, PDE=1.76
# Training Soft-Constraint PINN: 100%|▉| 14932/15000 [00:52<00:00, 274.91it/s, Loss=2.08e-04, PDE=1.76
# Training Soft-Constraint PINN: 100%|▉| 14932/15000 [00:52<00:00, 274.91it/s, Loss=1.93e-04, PDE=1.76
# Training Soft-Constraint PINN: 100%|▉| 14932/15000 [00:52<00:00, 274.91it/s, Loss=1.80e-04, PDE=1.76
# Training Soft-Constraint PINN: 100%|▉| 14932/15000 [00:52<00:00, 274.91it/s, Loss=1.78e-04, PDE=1.76
# Training Soft-Constraint PINN: 100%|▉| 14932/15000 [00:52<00:00, 274.91it/s, Loss=1.84e-04, PDE=1.76
# Training Soft-Constraint PINN: 100%|▉| 14932/15000 [00:52<00:00, 274.91it/s, Loss=1.91e-04, PDE=1.76
# Training Soft-Constraint PINN: 100%|▉| 14932/15000 [00:52<00:00, 274.91it/s, Loss=1.92e-04, PDE=1.76
# Training Soft-Constraint PINN: 100%|▉| 14932/15000 [00:52<00:00, 274.91it/s, Loss=1.88e-04, PDE=1.76
# Training Soft-Constraint PINN: 100%|▉| 14932/15000 [00:52<00:00, 274.91it/s, Loss=1.83e-04, PDE=1.76
# Training Soft-Constraint PINN: 100%|▉| 14932/15000 [00:52<00:00, 274.91it/s, Loss=1.78e-04, PDE=1.76
# Training Soft-Constraint PINN: 100%|▉| 14932/15000 [00:52<00:00, 274.91it/s, Loss=1.77e-04, PDE=1.76
# Training Soft-Constraint PINN: 100%|▉| 14961/15000 [00:52<00:00, 278.06it/s, Loss=1.77e-04, PDE=1.76
# Training Soft-Constraint PINN: 100%|▉| 14961/15000 [00:52<00:00, 278.06it/s, Loss=1.80e-04, PDE=1.76
# Training Soft-Constraint PINN: 100%|▉| 14961/15000 [00:52<00:00, 278.06it/s, Loss=1.83e-04, PDE=1.76
# Training Soft-Constraint PINN: 100%|▉| 14961/15000 [00:52<00:00, 278.06it/s, Loss=1.85e-04, PDE=1.76
# Training Soft-Constraint PINN: 100%|▉| 14961/15000 [00:52<00:00, 278.06it/s, Loss=1.82e-04, PDE=1.76
# Training Soft-Constraint PINN: 100%|▉| 14961/15000 [00:52<00:00, 278.06it/s, Loss=1.78e-04, PDE=1.76
# Training Soft-Constraint PINN: 100%|▉| 14961/15000 [00:52<00:00, 278.06it/s, Loss=1.76e-04, PDE=1.76
# Training Soft-Constraint PINN: 100%|▉| 14961/15000 [00:52<00:00, 278.06it/s, Loss=1.76e-04, PDE=1.76
# Training Soft-Constraint PINN: 100%|▉| 14961/15000 [00:52<00:00, 278.06it/s, Loss=1.78e-04, PDE=1.76
# Training Soft-Constraint PINN: 100%|▉| 14961/15000 [00:52<00:00, 278.06it/s, Loss=1.80e-04, PDE=1.76
# Training Soft-Constraint PINN: 100%|▉| 14961/15000 [00:52<00:00, 278.06it/s, Loss=1.80e-04, PDE=1.76
# Training Soft-Constraint PINN: 100%|▉| 14961/15000 [00:52<00:00, 278.06it/s, Loss=1.78e-04, PDE=1.76
# Training Soft-Constraint PINN: 100%|▉| 14961/15000 [00:52<00:00, 278.06it/s, Loss=1.77e-04, PDE=1.76
# Training Soft-Constraint PINN: 100%|▉| 14961/15000 [00:52<00:00, 278.06it/s, Loss=1.76e-04, PDE=1.76
# Training Soft-Constraint PINN: 100%|▉| 14961/15000 [00:52<00:00, 278.06it/s, Loss=1.76e-04, PDE=1.76
# Training Soft-Constraint PINN: 100%|▉| 14961/15000 [00:52<00:00, 278.06it/s, Loss=1.76e-04, PDE=1.76
# Training Soft-Constraint PINN: 100%|▉| 14961/15000 [00:52<00:00, 278.06it/s, Loss=1.77e-04, PDE=1.75
# Training Soft-Constraint PINN: 100%|▉| 14961/15000 [00:52<00:00, 278.06it/s, Loss=1.78e-04, PDE=1.75
# Training Soft-Constraint PINN: 100%|▉| 14961/15000 [00:52<00:00, 278.06it/s, Loss=1.77e-04, PDE=1.75
# Training Soft-Constraint PINN: 100%|▉| 14961/15000 [00:52<00:00, 278.06it/s, Loss=1.76e-04, PDE=1.75
# Training Soft-Constraint PINN: 100%|▉| 14961/15000 [00:52<00:00, 278.06it/s, Loss=1.76e-04, PDE=1.75
# Training Soft-Constraint PINN: 100%|▉| 14961/15000 [00:52<00:00, 278.06it/s, Loss=1.75e-04, PDE=1.75
# Training Soft-Constraint PINN: 100%|▉| 14961/15000 [00:52<00:00, 278.06it/s, Loss=1.76e-04, PDE=1.75
# Training Soft-Constraint PINN: 100%|▉| 14961/15000 [00:52<00:00, 278.06it/s, Loss=1.76e-04, PDE=1.75
# Training Soft-Constraint PINN: 100%|▉| 14961/15000 [00:52<00:00, 278.06it/s, Loss=1.76e-04, PDE=1.75
# Training Soft-Constraint PINN: 100%|▉| 14961/15000 [00:52<00:00, 278.06it/s, Loss=1.76e-04, PDE=1.75
# Training Soft-Constraint PINN: 100%|▉| 14961/15000 [00:52<00:00, 278.06it/s, Loss=1.76e-04, PDE=1.75
# Training Soft-Constraint PINN: 100%|▉| 14961/15000 [00:52<00:00, 278.06it/s, Loss=1.76e-04, PDE=1.75
# Training Soft-Constraint PINN: 100%|▉| 14961/15000 [00:52<00:00, 278.06it/s, Loss=1.75e-04, PDE=1.75
# Training Soft-Constraint PINN: 100%|▉| 14989/15000 [00:52<00:00, 276.34it/s, Loss=1.75e-04, PDE=1.75
# Training Soft-Constraint PINN: 100%|▉| 14989/15000 [00:52<00:00, 276.34it/s, Loss=1.75e-04, PDE=1.75
# Training Soft-Constraint PINN: 100%|▉| 14989/15000 [00:52<00:00, 276.34it/s, Loss=1.75e-04, PDE=1.75
# Training Soft-Constraint PINN: 100%|▉| 14989/15000 [00:52<00:00, 276.34it/s, Loss=1.76e-04, PDE=1.75
# Training Soft-Constraint PINN: 100%|▉| 14989/15000 [00:52<00:00, 276.34it/s, Loss=1.76e-04, PDE=1.75
# Training Soft-Constraint PINN: 100%|▉| 14989/15000 [00:52<00:00, 276.34it/s, Loss=1.76e-04, PDE=1.75
# Training Soft-Constraint PINN: 100%|▉| 14989/15000 [00:52<00:00, 276.34it/s, Loss=1.75e-04, PDE=1.75
# Training Soft-Constraint PINN: 100%|▉| 14989/15000 [00:52<00:00, 276.34it/s, Loss=1.75e-04, PDE=1.75
# Training Soft-Constraint PINN: 100%|▉| 14989/15000 [00:52<00:00, 276.34it/s, Loss=1.75e-04, PDE=1.75
# Training Soft-Constraint PINN: 100%|▉| 14989/15000 [00:52<00:00, 276.34it/s, Loss=1.75e-04, PDE=1.75
# Training Soft-Constraint PINN: 100%|▉| 14989/15000 [00:52<00:00, 276.34it/s, Loss=1.75e-04, PDE=1.75
# Training Soft-Constraint PINN: 100%|▉| 14989/15000 [00:52<00:00, 276.34it/s, Loss=1.75e-04, PDE=1.75
# Training Soft-Constraint PINN: 100%|█| 15000/15000 [00:52<00:00, 285.58it/s, Loss=1.75e-04, PDE=1.75
# Predicted u(0): 7.6964e-06
# Predicted u(1): 1.6399e-05

# %% [markdown]
# As we can see, the soft constraint approach produces a very accurate solution. However, the predicted values at the boundaries are not exactly zero, but very small numbers. This is the nature of soft enforcement—it gets close, but not perfect, depending on the loss weight and training.

# %% [markdown]
# ### **Stage 2: The Hard Constraint Approach (Strong Enforcement)**
#
# An alternative to penalty terms is to enforce the boundary conditions *by construction*. This is known as the "hard" or "strong" method.
#
# **How it works:**
# We redefine the network's output to create a "trial solution" $\tilde{u}(x)$ that is mathematically guaranteed to satisfy the Dirichlet boundary conditions, regardless of the neural network's raw output.
#
# For our problem with BCs $u(0)=0$ and $u(1)=0$, a suitable trial solution is:
# $$\tilde{u}(x) = D(x) \cdot \text{NN}(x; \theta)$$
# where $\text{NN}(x; \theta)$ is the output of a standard neural network and $D(x)$ is a function that is zero at the boundaries. A simple and effective choice is:
# $$D(x) = x(1-x)$$
# Our new model's output is $\tilde{u}(x) = x(1-x)\text{NN}(x; \theta)$.
#
#   * At $x=0$, $\tilde{u}(0) = 0 \cdot (1-0) \cdot \text{NN}(0) = 0$.
#   * At $x=1$, $\tilde{u}(1) = 1 \cdot (1-1) \cdot \text{NN}(1) = 0$.
#
# The BCs are now satisfied exactly. The training process simplifies significantly, as the **loss function now only contains the PDE residual term**. We no longer need a boundary loss or a weighting hyperparameter.
#
# #### **PINN Definition for Hard Constraints**
#
# We create a new model that wraps our original `PINN` and applies the hard constraint transformation.

# %%
class PINNHardConstraint(nn.Module):
    """PINN that enforces u(0)=0 and u(1)=0 by construction."""
    def __init__(self, base_network):
        super(PINNHardConstraint, self).__init__()
        self.base_network = base_network

    def forward(self, x):
        # Raw output from the base network
        nn_output = self.base_network(x)
        
        # Enforce u(0)=0 and u(1)=0
        # D(x) = x * (1 - x)
        # u_trial(x) = D(x) * NN(x)
        u_trial = x * (1.0 - x) * nn_output
        
        return u_trial

# %% [markdown]
# #### **Training the Hard-Constraint PINN**
#
# The training loop is now simpler, with only the PDE loss to minimize.

# %%
def train_pinn_hard(model, epochs=15000, lr=0.001):
    """Trains the PINN using the hard constraint method."""
    optimizer = optim.Adam(model.parameters(), lr=lr)
    
    # Collocation points
    n_interior = 500
    x_interior = torch.rand(n_interior, 1, device=device)
    
    print("\n--- Training Hard-Constraint PINN ---")
    losses = {'pde': []}
    
    pbar = tqdm(range(epochs), desc="Training Hard-Constraint PINN", ncols=100)
    for epoch in pbar:
        optimizer.zero_grad()
        
        # Compute loss (only PDE loss is needed)
        loss_pde = pde_loss(model, x_interior)
        
        # Backpropagation
        loss_pde.backward()
        optimizer.step()
        
        # Store and display loss
        losses['pde'].append(loss_pde.item())
        pbar.set_postfix({'PDE Loss': f'{loss_pde.item():.2e}'})
        
    pbar.close()
    return model, losses

# Instantiate the base network and the hard-constraint wrapper
base_pinn = PINN().to(device)
pinn_hard = PINNHardConstraint(base_pinn).to(device)

# Train the hard-constraint model
pinn_hard_trained, losses_hard = train_pinn_hard(pinn_hard)

# Get predictions
pinn_hard_trained.eval()
with torch.no_grad():
    u_pred_hard = pinn_hard_trained(x_test).cpu().numpy()

# Plot results for the hard-constraint model
plt.figure(figsize=(10, 6))
plt.plot(x_test_np, u_true_np, 'k-', label='Analytical Solution', linewidth=3)
plt.plot(x_test_np, u_pred_hard, 'b--', label='PINN (Hard Constraint)', linewidth=2.5)
plt.title('Hard Constraint PINN vs. Analytical Solution')
plt.xlabel('Position (x)')
plt.ylabel('Displacement (u)')
plt.legend()
plt.grid(True, alpha=0.5)
plt.show()

# Check boundary values
print(f"Predicted u(0): {u_pred_hard[0][0]:.4e}")
print(f"Predicted u(1): {u_pred_hard[-1][0]:.4e}")
# Out:
# --- Training Hard-Constraint PINN ---
# Training Hard-Constraint PINN:   0%|                                      | 0/15000 [00:00<?, ?it/s]
# Training Hard-Constraint PINN:   0%|                   | 0/15000 [00:00<?, ?it/s, PDE Loss=6.01e+00]
# Training Hard-Constraint PINN:   0%|                   | 0/15000 [00:00<?, ?it/s, PDE Loss=5.47e+00]
# Training Hard-Constraint PINN:   0%|                   | 0/15000 [00:00<?, ?it/s, PDE Loss=4.97e+00]
# Training Hard-Constraint PINN:   0%|                   | 0/15000 [00:00<?, ?it/s, PDE Loss=4.49e+00]
# Training Hard-Constraint PINN:   0%|                   | 0/15000 [00:00<?, ?it/s, PDE Loss=4.04e+00]
# Training Hard-Constraint PINN:   0%|                   | 0/15000 [00:00<?, ?it/s, PDE Loss=3.62e+00]
# Training Hard-Constraint PINN:   0%|                   | 0/15000 [00:00<?, ?it/s, PDE Loss=3.24e+00]
# Training Hard-Constraint PINN:   0%|                   | 0/15000 [00:00<?, ?it/s, PDE Loss=2.88e+00]
# Training Hard-Constraint PINN:   0%|                   | 0/15000 [00:00<?, ?it/s, PDE Loss=2.55e+00]
# Training Hard-Constraint PINN:   0%|                   | 0/15000 [00:00<?, ?it/s, PDE Loss=2.25e+00]
# Training Hard-Constraint PINN:   0%|                   | 0/15000 [00:00<?, ?it/s, PDE Loss=1.98e+00]
# Training Hard-Constraint PINN:   0%|                   | 0/15000 [00:00<?, ?it/s, PDE Loss=1.74e+00]
# Training Hard-Constraint PINN:   0%|                   | 0/15000 [00:00<?, ?it/s, PDE Loss=1.53e+00]
# Training Hard-Constraint PINN:   0%|                   | 0/15000 [00:00<?, ?it/s, PDE Loss=1.34e+00]
# Training Hard-Constraint PINN:   0%|                   | 0/15000 [00:00<?, ?it/s, PDE Loss=1.18e+00]
# Training Hard-Constraint PINN:   0%|                   | 0/15000 [00:00<?, ?it/s, PDE Loss=1.05e+00]
# Training Hard-Constraint PINN:   0%|                   | 0/15000 [00:00<?, ?it/s, PDE Loss=9.37e-01]
# Training Hard-Constraint PINN:   0%|                   | 0/15000 [00:00<?, ?it/s, PDE Loss=8.48e-01]
# Training Hard-Constraint PINN:   0%|                   | 0/15000 [00:00<?, ?it/s, PDE Loss=7.79e-01]
# Training Hard-Constraint PINN:   0%|                   | 0/15000 [00:00<?, ?it/s, PDE Loss=7.28e-01]
# Training Hard-Constraint PINN:   0%|                   | 0/15000 [00:00<?, ?it/s, PDE Loss=6.93e-01]
# Training Hard-Constraint PINN:   0%|                   | 0/15000 [00:00<?, ?it/s, PDE Loss=6.71e-01]
# Training Hard-Constraint PINN:   0%|                   | 0/15000 [00:00<?, ?it/s, PDE Loss=6.60e-01]
# Training Hard-Constraint PINN:   0%|                   | 0/15000 [00:00<?, ?it/s, PDE Loss=6.58e-01]
# Training Hard-Constraint PINN:   0%|                   | 0/15000 [00:00<?, ?it/s, PDE Loss=6.62e-01]
# Training Hard-Constraint PINN:   0%|                   | 0/15000 [00:00<?, ?it/s, PDE Loss=6.71e-01]
# Training Hard-Constraint PINN:   0%|                   | 0/15000 [00:00<?, ?it/s, PDE Loss=6.81e-01]
# Training Hard-Constraint PINN:   0%|                   | 0/15000 [00:00<?, ?it/s, PDE Loss=6.92e-01]
# Training Hard-Constraint PINN:   0%|                   | 0/15000 [00:00<?, ?it/s, PDE Loss=7.02e-01]
# Training Hard-Constraint PINN:   0%|         | 29/15000 [00:00<00:52, 286.72it/s, PDE Loss
-04]
# Training Hard-Constraint PINN:   3%|▏       | 428/15000 [00:01<00:45, 320.48it/s, PDE Loss=5.69e-04]
# Training Hard-Constraint PINN:   3%|▏       | 428/15000 [00:01<00:45, 320.48it/s, PDE Loss=5.61e-04]
# Training Hard-Constraint PINN:   3%|▏       | 428/15000 [00:01<00:45, 320.48it/s, PDE Loss=5.54e-04]
# Training Hard-Constraint PINN:   3%|▏       | 428/15000 [00:01<00:45, 320.48it/s, PDE Loss=5.47e-04]
# Training Hard-Constraint PINN:   3%|▏       | 428/15000 [00:01<00:45, 320.48it/s, PDE Loss=5.40e-04]
# Training Hard-Constraint PINN:   3%|▏       | 428/15000 [00:01<00:45, 320.48it/s, PDE Loss=5.33e-04]
# ...
# Training Hard-Constraint PINN:  99%|█████▉| 14837/15000 [00:46<00:00, 327.46it/s, PDE Loss=1.66e-06]
# Training Hard-Constraint PINN:  99%|█████▉| 14837/15000 [00:46<00:00, 327.46it/s, PDE Loss=2.45e-06]
# Training Hard-Constraint PINN:  99%|█████▉| 14837/15000 [00:46<00:00, 327.46it/s, PDE Loss=3.75e-06]
# Training Hard-Constraint PINN:  99%|█████▉| 14837/15000 [00:46<00:00, 327.46it/s, PDE Loss=5.90e-06]
# Training Hard-Constraint PINN:  99%|█████▉| 14837/15000 [00:46<00:00, 327.46it/s, PDE Loss=9.49e-06]
# Training Hard-Constraint PINN:  99%|█████▉| 14837/15000 [00:46<00:00, 327.46it/s, PDE Loss=1.54e-05]
# Training Hard-Constraint PINN:  99%|█████▉| 14837/15000 [00:46<00:00, 327.46it/s, PDE Loss=2.50e-05]
# Training Hard-Constraint PINN:  99%|█████▉| 14837/15000 [00:46<00:00, 327.46it/s, PDE Loss=4.03e-05]
# Training Hard-Constraint PINN:  99%|█████▉| 14837/15000 [00:46<00:00, 327.46it/s, PDE Loss=6.36e-05]
# Training Hard-Constraint PINN:  99%|█████▉| 14837/15000 [00:46<00:00, 327.46it/s, PDE Loss=9.64e-05]
# Training Hard-Constraint PINN:  99%|█████▉| 14837/15000 [00:46<00:00, 327.46it/s, PDE Loss=1.38e-04]
# Training Hard-Constraint PINN:  99%|█████▉| 14837/15000 [00:46<00:00, 327.46it/s, PDE Loss=1.80e-04]
# Training Hard-Constraint PINN:  99%|█████▉| 14837/15000 [00:46<00:00, 327.46it/s, PDE Loss=2.16e-04]
# Training Hard-Constraint PINN:  99%|█████▉| 14837/15000 [00:46<00:00, 327.46it/s, PDE Loss=2.38e-04]
# Training Hard-Constraint PINN:  99%|█████▉| 14837/15000 [00:46<00:00, 327.46it/s, PDE Loss=2.58e-04]
# Training Hard-Constraint PINN:  99%|█████▉| 14837/15000 [00:46<00:00, 327.46it/s, PDE Loss=2.80e-04]
# Training Hard-Constraint PINN:  99%|█████▉| 14837/15000 [00:46<00:00, 327.46it/s, PDE Loss=2.84e-04]
# Training Hard-Constraint PINN:  99%|█████▉| 14837/15000 [00:46<00:00, 327.46it/s, PDE Loss=2.37e-04]
# Training Hard-Constraint PINN:  99%|█████▉| 14837/15000 [00:46<00:00, 327.46it/s, PDE Loss=1.30e-04]
# Training Hard-Constraint PINN:  99%|█████▉| 14837/15000 [00:46<00:00, 327.46it/s, PDE Loss=2.98e-05]
# Training Hard-Constraint PINN:  99%|█████▉| 14837/15000 [00:46<00:00, 327.46it/s, PDE Loss=1.17e-05]
# Training Hard-Constraint PINN:  99%|█████▉| 14837/15000 [00:46<00:00, 327.46it/s, PDE Loss=7.54e-05]
# Training Hard-Constraint PINN:  99%|█████▉| 14870/15000 [00:46<00:00, 325.78it/s, PDE Loss=7.54e-05]
# Training Hard-Constraint PINN:  99%|█████▉| 14870/15000 [00:46<00:00, 325.78it/s, PDE Loss=1.40e-04]
# Training Hard-Constraint PINN:  99%|█████▉| 14870/15000 [00:46<00:00, 325.78it/s, PDE Loss=1.29e-04]
# Training Hard-Constraint PINN:  99%|█████▉| 14870/15000 [00:46<00:00, 325.78it/s, PDE Loss=5.91e-05]
# Training Hard-Constraint PINN:  99%|█████▉| 14870/15000 [00:46<00:00, 325.78it/s, PDE Loss=8.09e-06]
# Training Hard-Constraint PINN:  99%|█████▉| 14870/15000 [00:46<00:00, 325.78it/s, PDE Loss=2.01e-05]
# Training Hard-Constraint PINN:  99%|█████▉| 14870/15000 [00:46<00:00, 325.78it/s, PDE Loss=5.77e-05]
# Training Hard-Constraint PINN:  99%|█████▉| 14870/15000 [00:46<00:00, 325.78it/s, PDE Loss=6.61e-05]
# Training Hard-Constraint PINN:  99%|█████▉| 14870/15000 [00:46<00:00, 325.78it/s, PDE Loss=4.28e-05]
# Training Hard-Constraint PINN:  99%|█████▉| 14870/15000 [00:46<00:00, 325.78it/s, PDE Loss=2.23e-05]
# Training Hard-Constraint PINN:  99%|█████▉| 14870/15000 [00:46<00:00, 325.78it/s, PDE Loss=2.14e-05]
# Training Hard-Constraint PINN:  99%|█████▉| 14870/15000 [00:46<00:00, 325.78it/s, PDE Loss=2.56e-05]
# Training Hard-Constraint PINN:  99%|█████▉| 14870/15000 [00:46<00:00, 325.78it/s, PDE Loss=2.28e-05]
# Training Hard-Constraint PINN:  99%|█████▉| 14870/15000 [00:46<00:00, 325.78it/s, PDE Loss=2.08e-05]
# Training Hard-Constraint PINN:  99%|█████▉| 14870/15000 [00:46<00:00, 325.78it/s, PDE Loss=2.44e-05]
# Training Hard-Constraint PINN:  99%|█████▉| 14870/15000 [00:46<00:00, 325.78it/s, PDE Loss=2.37e-05]
# Training Hard-Constraint PINN:  99%|█████▉| 14870/15000 [00:46<00:00, 325.78it/s, PDE Loss=1.29e-05]
# Training Hard-Constraint PINN:  99%|█████▉| 14870/15000 [00:46<00:00, 325.78it/s, PDE Loss=3.98e-06]
# Training Hard-Constraint PINN:  99%|█████▉| 14870/15000 [00:46<00:00, 325.78it/s, PDE Loss=8.96e-06]
# Training Hard-Constraint PINN:  99%|█████▉| 14870/15000 [00:46<00:00, 325.78it/s, PDE Loss=1.92e-05]
# Training Hard-Constraint PINN:  99%|█████▉| 14870/15000 [00:46<00:00, 325.78it/s, PDE Loss=1.85e-05]
# Training Hard-Constraint PINN:  99%|█████▉| 14870/15000 [00:46<00:00, 325.78it/s, PDE Loss=7.17e-06]
# Training Hard-Constraint PINN:  99%|█████▉| 14870/15000 [00:46<00:00, 325.78it/s, PDE Loss=4.93e-07]
# Training Hard-Constraint PINN:  99%|█████▉| 14870/15000 [00:46<00:00, 325.78it/s, PDE Loss=5.09e-06]
# Training Hard-Constraint PINN:  99%|█████▉| 14870/15000 [00:46<00:00, 325.78it/s, PDE Loss=1.14e-05]
# Training Hard-Constraint PINN:  99%|█████▉| 14870/15000 [00:46<00:00, 325.78it/s, PDE Loss=1.03e-05]
# Training Hard-Constraint PINN:  99%|█████▉| 14870/15000 [00:46<00:00, 325.78it/s, PDE Loss=4.81e-06]
# Training Hard-Constraint PINN:  99%|█████▉| 14870/15000 [00:46<00:00, 325.78it/s, PDE Loss=2.65e-06]
# Training Hard-Constraint PINN:  99%|█████▉| 14870/15000 [00:46<00:00, 325.78it/s, PDE Loss=4.17e-06]
# Training Hard-Constraint PINN:  99%|█████▉| 14870/15000 [00:46<00:00, 325.78it/s, PDE Loss=4.94e-06]
# Training Hard-Constraint PINN:  99%|█████▉| 14870/15000 [00:46<00:00, 325.78it/s, PDE Loss=3.93e-06]
# Training Hard-Constraint PINN:  99%|█████▉| 14870/15000 [00:46<00:00, 325.78it/s, PDE Loss=3.61e-06]
# Training Hard-Constraint PINN:  99%|█████▉| 14870/15000 [00:46<00:00, 325.78it/s, PDE Loss=4.24e-06]
# Training Hard-Constraint PINN:  99%|█████▉| 14870/15000 [00:46<00:00, 325.78it/s, PDE Loss=3.63e-06]
# Training Hard-Constraint PINN:  99%|█████▉| 14870/15000 [00:46<00:00, 325.78it/s, PDE Loss=1.70e-06]
# Training Hard-Constraint PINN:  99%|█████▉| 14904/15000 [00:46<00:00, 327.88it/s, PDE Loss=1.70e-06]
# Training Hard-Constraint PINN:  99%|█████▉| 14904/15000 [00:46<00:00, 327.88it/s, PDE Loss=1.01e-06]
# Training Hard-Constraint PINN:  99%|█████▉| 14904/15000 [00:46<00:00, 327.88it/s, PDE Loss=2.46e-06]
# Training Hard-Constraint PINN:  99%|█████▉| 14904/15000 [00:46<00:00, 327.88it/s, PDE Loss=3.71e-06]
# Training Hard-Constraint PINN:  99%|█████▉| 14904/15000 [00:46<00:00, 327.88it/s, PDE Loss=2.80e-06]
# Training Hard-Constraint PINN:  99%|█████▉| 14904/15000 [00:46<00:00, 327.88it/s, PDE Loss=9.73e-07]
# Training Hard-Constraint PINN:  99%|█████▉| 14904/15000 [00:46<00:00, 327.88it/s, PDE Loss=5.28e-07]
# Training Hard-Constraint PINN:  99%|█████▉| 14904/15000 [00:46<00:00, 327.88it/s, PDE Loss=1.51e-06]
# Training Hard-Constraint PINN:  99%|█████▉| 14904/15000 [00:46<00:00, 327.88it/s, PDE Loss=2.19e-06]
# Training Hard-Constraint PINN:  99%|█████▉| 14904/15000 [00:46<00:00, 327.88it/s, PDE Loss=1.75e-06]
# Training Hard-Constraint PINN:  99%|█████▉| 14904/15000 [00:46<00:00, 327.88it/s, PDE Loss=1.06e-06]
# Training Hard-Constraint PINN:  99%|█████▉| 14904/15000 [00:46<00:00, 327.88it/s, PDE Loss=9.30e-07]
# Training Hard-Constraint PINN:  99%|█████▉| 14904/15000 [00:46<00:00, 327.88it/s, PDE Loss=1.08e-06]
# Training Hard-Constraint PINN:  99%|█████▉| 14904/15000 [00:46<00:00, 327.88it/s, PDE Loss=1.01e-06]
# Training Hard-Constraint PINN:  99%|█████▉| 14904/15000 [00:46<00:00, 327.88it/s, PDE Loss=8.55e-07]
# Training Hard-Constraint PINN:  99%|█████▉| 14904/15000 [00:46<00:00, 327.88it/s, PDE Loss=9.54e-07]
# Training Hard-Constraint PINN:  99%|█████▉| 14904/15000 [00:46<00:00, 327.88it/s, PDE Loss=1.13e-06]
# Training Hard-Constraint PINN:  99%|█████▉| 14904/15000 [00:46<00:00, 327.88it/s, PDE Loss=9.95e-07]
# Training Hard-Constraint PINN:  99%|█████▉| 14904/15000 [00:46<00:00, 327.88it/s, PDE Loss=6.10e-07]
# Training Hard-Constraint PINN:  99%|█████▉| 14904/15000 [00:46<00:00, 327.88it/s, PDE Loss=4.48e-07]
# Training Hard-Constraint PINN:  99%|█████▉| 14904/15000 [00:46<00:00, 327.88it/s, PDE Loss=6.70e-07]
# Training Hard-Constraint PINN:  99%|█████▉| 14904/15000 [00:46<00:00, 327.88it/s, PDE Loss=9.18e-07]
# Training Hard-Constraint PINN:  99%|█████▉| 14904/15000 [00:46<00:00, 327.88it/s, PDE Loss=8.56e-07]
# Training Hard-Constraint PINN:  99%|█████▉| 14904/15000 [00:46<00:00, 327.88it/s, PDE Loss=5.99e-07]
# Training Hard-Constraint PINN:  99%|█████▉| 14904/15000 [00:46<00:00, 327.88it/s, PDE Loss=4.66e-07]
# Training Hard-Constraint PINN:  99%|█████▉| 14904/15000 [00:46<00:00, 327.88it/s, PDE Loss=5.35e-07]
# Training Hard-Constraint PINN:  99%|█████▉| 14904/15000 [00:46<00:00, 327.88it/s, PDE Loss=6.25e-07]
# Training Hard-Constraint PINN:  99%|█████▉| 14904/15000 [00:46<00:00, 327.88it/s, PDE Loss=6.10e-07]
# Training Hard-Constraint PINN:  99%|█████▉| 14904/15000 [00:46<00:00, 327.88it/s, PDE Loss=5.56e-07]
# Training Hard-Constraint PINN:  99%|█████▉| 14904/15000 [00:46<00:00, 327.88it/s, PDE Loss=5.48e-07]
# Training Hard-Constraint PINN:  99%|█████▉| 14904/15000 [00:46<00:00, 327.88it/s, PDE Loss=5.57e-07]
# Training Hard-Constraint PINN:  99%|█████▉| 14904/15000 [00:46<00:00, 327.88it/s, PDE Loss=5.17e-07]
# Training Hard-Constraint PINN:  99%|█████▉| 14904/15000 [00:46<00:00, 327.88it/s, PDE Loss=4.56e-07]
# Training Hard-Constraint PINN:  99%|█████▉| 14904/15000 [00:46<00:00, 327.88it/s, PDE Loss=4.53e-07]
# Training Hard-Constraint PINN: 100%|█████▉| 14937/15000 [00:46<00:00, 325.23it/s, PDE Loss=4.53e-07]
# Training Hard-Constraint PINN: 100%|█████▉| 14937/15000 [00:46<00:00, 325.23it/s, PDE Loss=5.11e-07]
# Training Hard-Constraint PINN: 100%|█████▉| 14937/15000 [00:46<00:00, 325.23it/s, PDE Loss=5.47e-07]
# Training Hard-Constraint PINN: 100%|█████▉| 14937/15000 [00:46<00:00, 325.23it/s, PDE Loss=5.12e-07]
# Training Hard-Constraint PINN: 100%|█████▉| 14937/15000 [00:46<00:00, 325.23it/s, PDE Loss=4.48e-07]
# Training Hard-Constraint PINN: 100%|█████▉| 14937/15000 [00:46<00:00, 325.23it/s, PDE Loss=4.24e-07]
# Training Hard-Constraint PINN: 100%|█████▉| 14937/15000 [00:46<00:00, 325.23it/s, PDE Loss=4.50e-07]
# Training Hard-Constraint PINN: 100%|█████▉| 14937/15000 [00:46<00:00, 325.23it/s, PDE Loss=4.77e-07]
# Training Hard-Constraint PINN: 100%|█████▉| 14937/15000 [00:46<00:00, 325.23it/s, PDE Loss=4.73e-07]
# Training Hard-Constraint PINN: 100%|█████▉| 14937/15000 [00:46<00:00, 325.23it/s, PDE Loss=4.54e-07]
# Training Hard-Constraint PINN: 100%|█████▉| 14937/15000 [00:46<00:00, 325.23it/s, PDE Loss=4.46e-07]
# Training Hard-Constraint PINN: 100%|█████▉| 14937/15000 [00:46<00:00, 325.23it/s, PDE Loss=4.48e-07]
# Training Hard-Constraint PINN: 100%|█████▉| 14937/15000 [00:46<00:00, 325.23it/s, PDE Loss=4.43e-07]
# Training Hard-Constraint PINN: 100%|█████▉| 14937/15000 [00:46<00:00, 325.23it/s, PDE Loss=4.32e-07]
# Training Hard-Constraint PINN: 100%|█████▉| 14937/15000 [00:46<00:00, 325.23it/s, PDE Loss=4.28e-07]
# Training Hard-Constraint PINN: 100%|█████▉| 14937/15000 [00:46<00:00, 325.23it/s, PDE Loss=4.38e-07]
# Training Hard-Constraint PINN: 100%|█████▉| 14937/15000 [00:46<00:00, 325.23it/s, PDE Loss=4.48e-07]
# Training Hard-Constraint PINN: 100%|█████▉| 14937/15000 [00:46<00:00, 325.23it/s, PDE Loss=4.45e-07]
# Training Hard-Constraint PINN: 100%|█████▉| 14937/15000 [00:46<00:00, 325.23it/s, PDE Loss=4.31e-07]
# Training Hard-Constraint PINN: 100%|█████▉| 14937/15000 [00:46<00:00, 325.23it/s, PDE Loss=4.21e-07]
# Training Hard-Constraint PINN: 100%|█████▉| 14937/15000 [00:46<00:00, 325.23it/s, PDE Loss=4.23e-07]
# Training Hard-Constraint PINN: 100%|█████▉| 14937/15000 [00:46<00:00, 325.23it/s, PDE Loss=4.30e-07]
# Training Hard-Constraint PINN: 100%|█████▉| 14937/15000 [00:46<00:00, 325.23it/s, PDE Loss=4.33e-07]
# Training Hard-Constraint PINN: 100%|█████▉| 14937/15000 [00:46<00:00, 325.23it/s, PDE Loss=4.29e-07]
# Training Hard-Constraint PINN: 100%|█████▉| 14937/15000 [00:46<00:00, 325.23it/s, PDE Loss=4.26e-07]
# Training Hard-Constraint PINN: 100%|█████▉| 14937/15000 [00:46<00:00, 325.23it/s, PDE Loss=4.26e-07]
# Training Hard-Constraint PINN: 100%|█████▉| 14937/15000 [00:46<00:00, 325.23it/s, PDE Loss=4.26e-07]
# Training Hard-Constraint PINN: 100%|█████▉| 14937/15000 [00:46<00:00, 325.23it/s, PDE Loss=4.24e-07]
# Training Hard-Constraint PINN: 100%|█████▉| 14937/15000 [00:46<00:00, 325.23it/s, PDE Loss=4.21e-07]
# Training Hard-Constraint PINN: 100%|█████▉| 14937/15000 [00:46<00:00, 325.23it/s, PDE Loss=4.21e-07]
# Training Hard-Constraint PINN: 100%|█████▉| 14937/15000 [00:46<00:00, 325.23it/s, PDE Loss=4.23e-07]
# Training Hard-Constraint PINN: 100%|█████▉| 14937/15000 [00:46<00:00, 325.23it/s, PDE Loss=4.25e-07]
# Training Hard-Constraint PINN: 100%|█████▉| 14937/15000 [00:46<00:00, 325.23it/s, PDE Loss=4.24e-07]
# Training Hard-Constraint PINN: 100%|█████▉| 14937/15000 [00:46<00:00, 325.23it/s, PDE Loss=4.22e-07]
# Training Hard-Constraint PINN: 100%|█████▉| 14937/15000 [00:46<00:00, 325.23it/s, PDE Loss=4.19e-07]
# Training Hard-Constraint PINN: 100%|█████▉| 14971/15000 [00:46<00:00, 329.30it/s, PDE Loss=4.19e-07]
# Training Hard-Constraint PINN: 100%|█████▉| 14971/15000 [00:46<00:00, 329.30it/s, PDE Loss=4.19e-07]
# Training Hard-Constraint PINN: 100%|█████▉| 14971/15000 [00:46<00:00, 329.30it/s, PDE Loss=4.20e-07]
# Training Hard-Constraint PINN: 100%|█████▉| 14971/15000 [00:46<00:00, 329.30it/s, PDE Loss=4.21e-07]
# Training Hard-Constraint PINN: 100%|█████▉| 14971/15000 [00:46<00:00, 329.30it/s, PDE Loss=4.20e-07]
# Training Hard-Constraint PINN: 100%|█████▉| 14971/15000 [00:46<00:00, 329.30it/s, PDE Loss=4.20e-07]
# Training Hard-Constraint PINN: 100%|█████▉| 14971/15000 [00:46<00:00, 329.30it/s, PDE Loss=4.20e-07]
# Training Hard-Constraint PINN: 100%|█████▉| 14971/15000 [00:46<00:00, 329.30it/s, PDE Loss=4.20e-07]
# Training Hard-Constraint PINN: 100%|█████▉| 14971/15000 [00:46<00:00, 329.30it/s, PDE Loss=4.20e-07]
# Training Hard-Constraint PINN: 100%|█████▉| 14971/15000 [00:46<00:00, 329.30it/s, PDE Loss=4.19e-07]
# Training Hard-Constraint PINN: 100%|█████▉| 14971/15000 [00:46<00:00, 329.30it/s, PDE Loss=4.18e-07]
# Training Hard-Constraint PINN: 100%|█████▉| 14971/15000 [00:46<00:00, 329.30it/s, PDE Loss=4.18e-07]
# Training Hard-Constraint PINN: 100%|█████▉| 14971/15000 [00:46<00:00, 329.30it/s, PDE Loss=4.19e-07]
# Training Hard-Constraint PINN: 100%|█████▉| 14971/15000 [00:46<00:00, 329.30it/s, PDE Loss=4.19e-07]
# Training Hard-Constraint PINN: 100%|█████▉| 14971/15000 [00:46<00:00, 329.30it/s, PDE Loss=4.19e-07]
# Training Hard-Constraint PINN: 100%|█████▉| 14971/15000 [00:46<00:00, 329.30it/s, PDE Loss=4.18e-07]
# Training Hard-Constraint PINN: 100%|█████▉| 14971/15000 [00:46<00:00, 329.30it/s, PDE Loss=4.18e-07]
# Training Hard-Constraint PINN: 100%|█████▉| 14971/15000 [00:46<00:00, 329.30it/s, PDE Loss=4.18e-07]
# Training Hard-Constraint PINN: 100%|█████▉| 14971/15000 [00:46<00:00, 329.30it/s, PDE Loss=4.18e-07]
# Training Hard-Constraint PINN: 100%|█████▉| 14971/15000 [00:46<00:00, 329.30it/s, PDE Loss=4.17e-07]
# Training Hard-Constraint PINN: 100%|█████▉| 14971/15000 [00:46<00:00, 329.30it/s, PDE Loss=4.17e-07]
# Training Hard-Constraint PINN: 100%|█████▉| 14971/15000 [00:46<00:00, 329.30it/s, PDE Loss=4.17e-07]
# Training Hard-Constraint PINN: 100%|█████▉| 14971/15000 [00:46<00:00, 329.30it/s, PDE Loss=4.17e-07]
# Training Hard-Constraint PINN: 100%|█████▉| 14971/15000 [00:46<00:00, 329.30it/s, PDE Loss=4.17e-07]
# Training Hard-Constraint PINN: 100%|█████▉| 14971/15000 [00:46<00:00, 329.30it/s, PDE Loss=4.17e-07]
# Training Hard-Constraint PINN: 100%|█████▉| 14971/15000 [00:46<00:00, 329.30it/s, PDE Loss=4.17e-07]
# Training Hard-Constraint PINN: 100%|█████▉| 14971/15000 [00:46<00:00, 329.30it/s, PDE Loss=4.17e-07]
# Training Hard-Constraint PINN: 100%|█████▉| 14971/15000 [00:46<00:00, 329.30it/s, PDE Loss=4.17e-07]
# Training Hard-Constraint PINN: 100%|█████▉| 14971/15000 [00:46<00:00, 329.30it/s, PDE Loss=4.17e-07]
# Training Hard-Constraint PINN: 100%|█████▉| 14971/15000 [00:46<00:00, 329.30it/s, PDE Loss=4.17e-07]
# Training Hard-Constraint PINN: 100%|██████| 15000/15000 [00:46<00:00, 322.68it/s, PDE Loss=4.17e-07]
# Predicted u(0): 0.0000e+00
# Predicted u(1): 0.0000e+00

# %% [markdown]
# With the hard constraint, the predicted values at the boundaries are exactly zero, as expected from the design.

# %% [markdown]
# ### **Stage 3: Comparison and Analysis**
#
# Now let's directly compare the performance of the soft and hard constraint methods.
#
# #### **Solution and Error Comparison**
#
# We plot both PINN solutions against the analytical solution and also visualize their absolute errors.

# %%
# Calculate absolute errors
error_soft = np.abs(u_pred_soft - u_true_np.reshape(-1, 1))
error_hard = np.abs(u_pred_hard - u_true_np.reshape(-1, 1))

# Create comparison plots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))

# Plot 1: Solution Comparison
ax1.plot(x_test_np, u_true_np, 'k-', label='Analytical Solution', linewidth=3, alpha=0.8)
ax1.plot(x_test_np, u_pred_soft, 'r--', label='Soft Constraint', linewidth=2)
ax1.plot(x_test_np, u_pred_hard, 'b:', label='Hard Constraint', linewidth=3)
ax1.set_title('Solution Comparison')
ax1.set_xlabel('Position (x)')
ax1.set_ylabel('Displacement (u)')
ax1.legend()
ax1.grid(True, alpha=0.5)

# Plot 2: Absolute Error Comparison
ax2.plot(x_test_np, error_soft, 'r-', label='Soft Constraint Error', linewidth=2)
ax2.plot(x_test_np, error_hard, 'b-', label='Hard Constraint Error', linewidth=2)
ax2.set_title('Absolute Error Comparison')
ax2.set_xlabel('Position (x)')
ax2.set_ylabel('Absolute Error')
ax2.set_yscale('log')
ax2.legend()
ax2.grid(True, which="both", ls="--", alpha=0.5)

plt.tight_layout()
plt.show()

# Quantitative Error Metrics
rmse_soft = np.sqrt(np.mean(error_soft**2))
rmse_hard = np.sqrt(np.mean(error_hard**2))
u0_soft = u_pred_soft[0][0]
u1_soft = u_pred_soft[-1][0]
u0_hard = u_pred_hard[0][0]
u1_hard = u_pred_hard[-1][0]

print("--- Quantitative Comparison ---")
print(f"Method             | RMSE      | u(0) Value | u(1) Value")
print("-------------------|-----------|------------|-----------")
print(f"Soft Constraint    | {rmse_soft:.3e} | {u0_soft:.3e}  | {u1_soft:.3e}")
print(f"Hard Constraint    | {rmse_hard:.3e} | {u0_hard:.3e} | {u1_hard:.3e}")
# Out:
# --- Quantitative Comparison ---
# Method             | RMSE      | u(0) Value | u(1) Value
# -------------------|-----------|------------|-----------
# Soft Constraint    | 4.064e-05 | 7.696e-06  | 1.640e-05
# Hard Constraint    | 2.810e-06 | 0.000e+00 | 0.000e+00

# %% [markdown]
# #### **Discussion of Results**
#
# Both methods achieve a high degree of accuracy for this problem. The hard constraint method shows a slightly lower overall error (RMSE) and, by design, has zero error at the boundaries.
#
# **Trade-offs:**
#
#   * **Soft Constraints (Weak Enforcement):**
#
#       * **Pros:** Very flexible. The same approach can be used for different types of boundary conditions (Dirichlet, Neumann, Robin) without changing the network architecture. It's easy to implement.
#       * **Cons:** Requires careful tuning of the loss weight ($\lambda\_{BC}$). If the weight is too small, the BCs are not well-enforced. If it's too large, it can dominate the optimization and hinder convergence of the PDE part. Satisfaction of BCs is only approximate.
#
#   * **Hard Constraints (Strong Enforcement):**
#
#       * **Pros:** Guarantees exact satisfaction of Dirichlet BCs. Simplifies the loss function, removing the need to balance competing PDE and BC loss terms, which can lead to more stable and faster training.
#       * **Cons:** Less flexible. It requires designing a specific trial function $\tilde{u}(x)$ for the exact geometry and boundary conditions of the problem. This can become very difficult or impossible for complex domains or more complicated BCs.
#
# For problems with simple geometries and Dirichlet boundary conditions, the **hard constraint method is often the superior choice** due to its robustness and simplified training dynamics. For problems with complex geometries or other types of boundary conditions, the **soft constraint method provides a more versatile and straightforward framework**
